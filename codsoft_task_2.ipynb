# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from collections import namedtuple
from IPython.display import display

# %% [markdown]
# **UNDERSTAND THE DATA**

# %%
df=pd.read_excel('/content/IMDb Movies India.xlsx')

# %%
#shape is used to obtain dimensions of pandas and numpy type objects
df.shape
# Out:
# (15509, 10)

# %%
#head() method returns the first five rows
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                         #Homecoming -2021.0   90 min   Drama, Musical
# 3                             #Yaaram -2019.0  110 min  Comedy, Romance
# 4                   ...And Once Again -2010.0  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# 4      Antara Mali

# %%
#tail() methods returns the last five rows
df.tail()
# Out:
#                       Name    Year Duration          Genre  Rating Votes  \
# 15504  Zulm Ko Jala Doonga -1988.0      NaN         Action     4.6    11
# 15505                Zulmi -1999.0  129 min  Action, Drama     4.5   655
# 15506            Zulmi Raj -2005.0      NaN         Action     NaN   NaN
# 15507        Zulmi Shikari -1988.0      NaN         Action     NaN   NaN
# 15508         Zulm-O-Sitam -1998.0  130 min  Action, Drama     6.2    20
#
#             Director           Actor 1         Actor 2        Actor 3
# 15504  Mahendra Shah  Naseeruddin Shah   Sumeet Saigal  Suparna Anand
# 15505     Kuku Kohli      Akshay Kumar  Twinkle Khanna    Aruna Irani
# 15506     Kiran Thej   Sangeeta Tiwari             NaN            NaN
# 15507            NaN               NaN             NaN            NaN
# 15508   K.C. Bokadia        Dharmendra      Jaya Prada    Arjun Sarja

# %%
#column function is used return the column labels of the given dataframe.
df.columns.values
# Out:
# array(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'], dtype=object)

# %%
#this function is used to return the column labels in the form of list
df.columns.values.tolist()
# Out:
# ['Name',
#  'Year',
#  'Duration',
#  'Genre',
#  'Rating',
#  'Votes',
#  'Director',
#  'Actor 1',
#  'Actor 2',
#  'Actor 3']

# %%
#describe() method is used to returns description of data in dataframe
df.describe()
# Out:
#                Year       Rating
# count  14981.000000  7919.000000
# mean   -1987.012215     5.841621
# std       25.416689     1.381777
# min    -2022.000000     1.100000
# 25%    -2009.000000     4.900000
# 50%    -1991.000000     6.000000
# 75%    -1968.000000     6.800000
# max    -1913.000000    10.000000

# %%
#info() method is used to print information about the data frame
df.info
# Out:
# <bound method DataFrame.info of                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                             #Homecoming -2021.0   90 min   Drama, Musical
# 3                                 #Yaaram -2019.0  110 min  Comedy, Romance
# 4                       ...And Once Again -2010.0  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga -1988.0      NaN           Action
# 15505                               Zulmi -1999.0  129 min    Action, Drama
# 15506                           Zulmi Raj -2005.0      NaN           Action
# 15507                       Zulmi Shikari -1988.0      NaN           Action
# 15508                        Zulm-O-Sitam -1998.0  130 min    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15509 rows x 10 columns]>

# %% [markdown]
# **CHECK MISSING VALUES**

# %%
# isnull() function is used to check missing values
df.isnull()
# Out:
#         Name   Year  Duration  Genre  Rating  Votes  Director  Actor 1  \
# 0      False   True      True  False    True   True     False    False
# 1      False  False     False  False   False  False     False    False
# 2      False  False     False  False    True   True     False    False
# 3      False  False     False  False   False  False     False    False
# 4      False  False     False  False    True   True     False    False
# ...      ...    ...       ...    ...     ...    ...       ...      ...
# 15504  False  False      True  False   False  False     False    False
# 15505  False  False     False  False   False  False     False    False
# 15506  False  False      True  False    True   True     False    False
# 15507  False  False      True  False    True   True      True     True
# 15508  False  False     False  False   False  False     False    False
#
#        Actor 2  Actor 3
# 0        False    False
# 1        False    False
# 2        False    False
# 3        False    False
# 4        False    False
# ...        ...      ...
# 15504    False    False
# 15505    False    False
# 15506     True     True
# 15507     True     True
# 15508    False    False
#
# [15509 rows x 10 columns]

# %%
#notnull() is used to check the non-missing values
df.notnull()
# Out:
#        Name   Year  Duration  Genre  Rating  Votes  Director  Actor 1  \
# 0      True  False     False   True   False  False      True     True
# 1      True   True      True   True    True   True      True     True
# 2      True   True      True   True   False  False      True     True
# 3      True   True      True   True    True   True      True     True
# 4      True   True      True   True   False  False      True     True
# ...     ...    ...       ...    ...     ...    ...       ...      ...
# 15504  True   True     False   True    True   True      True     True
# 15505  True   True      True   True    True   True      True     True
# 15506  True   True     False   True   False  False      True     True
# 15507  True   True     False   True   False  False     False    False
# 15508  True   True      True   True    True   True      True     True
#
#        Actor 2  Actor 3
# 0         True     True
# 1         True     True
# 2         True     True
# 3         True     True
# 4         True     True
# ...        ...      ...
# 15504     True     True
# 15505     True     True
# 15506    False    False
# 15507    False    False
# 15508     True     True
#
# [15509 rows x 10 columns]

# %%
#this function is used to check if there is any missing value
df.isnull().values.any()
# Out:
# True

# %%
#this function is used to check how many values are missing values in data
df.isnull().sum().sum()
# Out:
# 33523

# %%
#this function checks the missing variables
df.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %% [markdown]
# **DROPPING THE DATA**

# %%
#this function is used to drop the duplicate rows
df.drop_duplicates(inplace=True)

# %%
#this function is used to drop the rows given as index
df=df.drop(df.index[[1,2,3]])
print(df)
# Out:
#                        Name    Year Duration                   Genre  Rating  \
# 0                               NaN      NaN                   Drama     NaN
# 4         ...And Once Again -2010.0  105 min                   Drama     NaN
# 5      ...Aur Pyaar Ho Gaya -1997.0  147 min  Comedy, Drama, Musical     4.7
# 6                 ...Yahaan -2005.0  142 min     Drama, Romance, War     7.4
# 7            .in for Motion -2008.0   59 min             Documentary     NaN
# ...                     ...     ...      ...                     ...     ...
# 15504   Zulm Ko Jala Doonga -1988.0      NaN                  Action     4.6
# 15505                 Zulmi -1999.0  129 min           Action, Drama     4.5
# 15506             Zulmi Raj -2005.0      NaN                  Action     NaN
# 15507         Zulmi Shikari -1988.0      NaN                  Action     NaN
# 15508          Zulm-O-Sitam -1998.0  130 min           Action, Drama     6.2
#
#       Votes        Director           Actor 1                 Actor 2  \
# 0       NaN   J.S. Randhawa          Manmauji                  Birbal
# 4       NaN    Amol Palekar      Rajat Kapoor      Rituparna Sengupta
# 5       827    Rahul Rawail        Bobby Deol  Aishwarya Rai Bachchan
# 6      1086  Shoojit Sircar   Jimmy Sheirgill          Minissha Lamba
# 7       NaN   Anirban Datta               NaN                     NaN
# ...     ...             ...               ...                     ...
# 15504    11   Mahendra Shah  Naseeruddin Shah           Sumeet Saigal
# 15505   655      Kuku Kohli      Akshay Kumar          Twinkle Khanna
# 15506   NaN      Kiran Thej   Sangeeta Tiwari                     NaN
# 15507   NaN             NaN               NaN                     NaN
# 15508    20    K.C. Bokadia        Dharmendra              Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 4          Antara Mali
# 5        Shammi Kapoor
# 6       Yashpal Sharma
# 7                  NaN
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15500 rows x 10 columns]

# %%
#this function is used to drop the 2nd to the 10th row
df=df.drop(df.index[range(1,11)])
print(df)
# Out:
#                       Name    Year Duration                   Genre  Rating  \
# 0                              NaN      NaN                   Drama     NaN
# 14              101 Ratein -1990.0      NaN                Thriller     NaN
# 15             102 Not Out -2018.0  102 min           Comedy, Drama     7.4
# 16             108 Limited     NaN      NaN                     NaN     NaN
# 17         108 Teerthyatra -1987.0      NaN  Comedy, Drama, Fantasy     NaN
# ...                    ...     ...      ...                     ...     ...
# 15504  Zulm Ko Jala Doonga -1988.0      NaN                  Action     4.6
# 15505                Zulmi -1999.0  129 min           Action, Drama     4.5
# 15506            Zulmi Raj -2005.0      NaN                  Action     NaN
# 15507        Zulmi Shikari -1988.0      NaN                  Action     NaN
# 15508         Zulm-O-Sitam -1998.0  130 min           Action, Drama     6.2
#
#       Votes       Director           Actor 1         Actor 2          Actor 3
# 0       NaN  J.S. Randhawa          Manmauji          Birbal  Rajendra Bhatia
# 14      NaN         Harish         Saraswati    Disco Shanti              NaN
# 15     6619   Umesh Shukla  Amitabh Bachchan    Rishi Kapoor       Vijay Raaz
# 16      NaN    Anand Anddy        Vijay Raaz   Sanjay Mishra     Brahmanandam
# 17      NaN        Rajpati      Pravin Anand     Nayan Bhatt            Jeetu
# ...     ...            ...               ...             ...              ...
# 15504    11  Mahendra Shah  Naseeruddin Shah   Sumeet Saigal    Suparna Anand
# 15505   655     Kuku Kohli      Akshay Kumar  Twinkle Khanna      Aruna Irani
# 15506   NaN     Kiran Thej   Sangeeta Tiwari             NaN              NaN
# 15507   NaN            NaN               NaN             NaN              NaN
# 15508    20   K.C. Bokadia        Dharmendra      Jaya Prada      Arjun Sarja
#
# [15490 rows x 10 columns]

# %% [markdown]
# **SUBSETTING**

# %%
#shows the first row of information
df.iloc[0]
# Out:
# Name
# Year                    NaN
# Duration                NaN
# Genre                 Drama
# Rating                  NaN
# Votes                   NaN
# Director      J.S. Randhawa
# Actor 1            Manmauji
# Actor 2              Birbal
# Actor 3     Rajendra Bhatia
# Name: 0, dtype: object

# %%
#shows the chosen rows
df.iloc[[0,1,2]]
# Out:
#            Name    Year Duration          Genre  Rating Votes       Director  \
# 0                   NaN      NaN          Drama     NaN   NaN  J.S. Randhawa
# 14   101 Ratein -1990.0      NaN       Thriller     NaN   NaN         Harish
# 15  102 Not Out -2018.0  102 min  Comedy, Drama     7.4  6619   Umesh Shukla
#
#              Actor 1       Actor 2          Actor 3
# 0           Manmauji        Birbal  Rajendra Bhatia
# 14         Saraswati  Disco Shanti              NaN
# 15  Amitabh Bachchan  Rishi Kapoor       Vijay Raaz

# %%
#prints the first column
df.iloc[:,0]
# Out:
# 0
# 14                101 Ratein
# 15               102 Not Out
# 16               108 Limited
# 17           108 Teerthyatra
#                 ...
# 15504    Zulm Ko Jala Doonga
# 15505                  Zulmi
# 15506              Zulmi Raj
# 15507          Zulmi Shikari
# 15508           Zulm-O-Sitam
# Name: Name, Length: 15490, dtype: object

# %%
#prints the first 6 columns
df.iloc[:,0:6]
# Out:
#                       Name    Year Duration                   Genre  Rating  \
# 0                              NaN      NaN                   Drama     NaN
# 14              101 Ratein -1990.0      NaN                Thriller     NaN
# 15             102 Not Out -2018.0  102 min           Comedy, Drama     7.4
# 16             108 Limited     NaN      NaN                     NaN     NaN
# 17         108 Teerthyatra -1987.0      NaN  Comedy, Drama, Fantasy     NaN
# ...                    ...     ...      ...                     ...     ...
# 15504  Zulm Ko Jala Doonga -1988.0      NaN                  Action     4.6
# 15505                Zulmi -1999.0  129 min           Action, Drama     4.5
# 15506            Zulmi Raj -2005.0      NaN                  Action     NaN
# 15507        Zulmi Shikari -1988.0      NaN                  Action     NaN
# 15508         Zulm-O-Sitam -1998.0  130 min           Action, Drama     6.2
#
#       Votes
# 0       NaN
# 14      NaN
# 15     6619
# 16      NaN
# 17      NaN
# ...     ...
# 15504    11
# 15505   655
# 15506   NaN
# 15507   NaN
# 15508    20
#
# [15490 rows x 6 columns]

# %%
#shows the first row
df.loc[0]
# Out:
# Name
# Year                    NaN
# Duration                NaN
# Genre                 Drama
# Rating                  NaN
# Votes                   NaN
# Director      J.S. Randhawa
# Actor 1            Manmauji
# Actor 2              Birbal
# Actor 3     Rajendra Bhatia
# Name: 0, dtype: object

# %% [markdown]
# **MANAGING THE DATA**

# %%
#looking for datatypes
print(df.dtypes)
# Out:
# Name         object
# Year        float64
# Duration     object
# Genre        object
# Rating      float64
# Votes        object
# Director     object
# Actor 1      object
# Actor 2      object
# Actor 3      object
# dtype: object

# %% [markdown]
# **VISUALIZATION**

# %%
def Talents(column):
    global df
    df[column].value_counts().sort_values(ascending=False)[:10].plot(kind="bar", figsize=(20,6), edgecolor="k")
    plt.xticks(rotation=0)
    plt.title("Top Ten {}".format(column))
    plt.xlabel(column)
    plt.ylabel("Count")
    plt.show()

# %%
def Histo(column):
    global df
    plt.figure(figsize=(20,6))
    plt.hist(df[column], edgecolor="k")
    plt.xticks(rotation=0)
    plt.title("Histogram of {}".format(column))
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
def Scatter(x, y, c=None):
    global df
    plt.figure(figsize=(20,6))
    plt.scatter(df[x], df[y], edgecolor="k", c=c)
    plt.xticks(rotation=0)
    plt.title("Scatter plot X:{} / Y:{}".format(x, y))
    plt.xlabel(x)
    plt.ylabel(y)
    plt.show()

# %%
Talents("Director")
Talents("Actor 1")
Talents("Actor 2")
Talents("Actor 3")
Histo("Year")

# %% [markdown]
# **CORRELATION MATRIX**

# %%
import seaborn as sns

sns.pairplot(df)
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = df[numeric_columns].corr(method='spearman')
